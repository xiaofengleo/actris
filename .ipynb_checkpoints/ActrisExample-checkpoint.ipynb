# %%
############
## This script read metadata from netCDF file, convert it into rdf triple store.
## Xiaofeng Liao
## 25 Feb, 2020
###############

# %%
pip install netCDF4
pip install rdflib
pip install PyYAML
# Out:
#   File "<ipython-input-2-102418f64239>", line 1
#     pip install netCDF4
#               ^
# SyntaxError: invalid syntax

# %%
import yaml
import netCDF4
import rdflib
from rdflib import Graph, Literal, BNode, Namespace, RDF, URIRef, plugin, ConjunctiveGraph
from rdflib.namespace import DC, FOAF, RDFS
from rdflib.store import Store
#from rdflib.namespace import RDFS
from rdflib import Namespace

# %%
import nltk; nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /Users/admin/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /Users/admin/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to /Users/admin/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /Users/admin/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pil to /Users/admin/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package ptb to /Users/admin/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package qc to /Users/admin/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rte to /Users/admin/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to /Users/admin/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to /Users/admin/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    | Downloading package rslp to /Users/admin/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/admin/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
##########
## DMPS ##
##########

ae = Namespace("http://actrisexample.eu/ns/")

vocab = dict()
vocab[None] = {'uri': URIRef('http://actrisexample.eu/ns/NULL'), 'label': 'None'}
vocab['NULL'] = {'uri': URIRef('http://actrisexample.eu/ns/NULL'), 'label': 'NULL'}

store = plugin.get('IOMemory', Store)()

g = ConjunctiveGraph(store)
g.bind('envri', 'http://envri.eu/ns/')
g.bind('ae','http://actrisexample.eu/ns/')
g.bind('dcterms', 'http://purl.org/dc/terms/')
g.bind('foaf', 'http://xmlns.com/foaf/0.1/')
g.bind('skos', 'http://www.w3.org/2004/02/skos/core#')

# with open('vocab.yaml', 'r') as f:
#     for key, value in yaml.safe_load(f).items():
#         v = dict()
#         v['uri'] = URIRef(value['uri'])
#         v['label'] = value['label']
#         vocab[key] = v
#         g.add((vocab[key]['uri'], RDFS.label, Literal(vocab[key]['label'])))

print('Instrument DMPS and variable particle number size distribution:\nFilename: NO0058G.20070218000000.20181205100800.dmps.particle_number_size_distribution.aerosol.3y.1h.NO01L_DMPS_Troll1.NO01L_dmps_DMPS_Troll1.lev2.nc\n\n')

# use the netcdf4 lib to extract netcdf via the opendap protocol
dataset = netCDF4.Dataset('NO0058G.20070218000000.20181205100800.dmps.particle_number_size_distribution.aerosol.3y.1h.NO01L_DMPS_Troll1.NO01L_dmps_DMPS_Troll1.lev2.nc','r','NETCDF4')

# fetch global attributes from netcdf on the thredds server
global_attr = dataset.ncattrs()

# Create an identifier to use as the subject for Donna.
DMPS = BNode()
particle_number_size_distribution = BNode()
aerosol = BNode()


for attr in global_attr:
    print('{0}: {1}'.format(attr, dataset.getncattr(attr)))
    if attr=="summary":
        print(attr)
        print(dataset.getncattr(attr))
        sentence = dataset.getncattr(attr)
        tokens = nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(tokens)
        print("\n###########\n")
        print("pos tagging:")
        #print(tagged)
        print("\n###########\n")
        #print("entities:")
        entities = nltk.chunk.ne_chunk(tagged)
        #print(entities)
    # Add triples using store's add method.
        g.add( (DMPS, ae.measures, Literal("particle_number_size_distribution")) )
        g.add( (particle_number_size_distribution, ae.belongsto, aerosol))
    #g.add( (donna, FOAF.nick, Literal("donna", lang="foo")) )
    #g.add( (donna, FOAF.name, Literal("Donna Fales")) )
    #g.add( (donna, FOAF.mbox, URIRef("mailto:donna@example.org")) )

# Iterate over triples in store and print them out.
print("--- printing raw triples ---")
for s, p, o in g:
    print((s, p, o))

print("graph has %s statements." % len(g))

g.serialize(destination='data.ttl', format='ttl')

#print( g.serialize(format='ttl') )

##################
## Nephelometer ##
##################

# print('\nInstrument Nephelometer and variable aerosol scattering coefficient:\nFilename: https://thredds.nilu.no/thredds/dodsC/ebas/DE0043G.20060101000000.20160708144500.nephelometer..aerosol.4y.1h.DE09L_tsi_neph_3563_aerosol.DE09L_nephelometer.lev2.nc')

# # use the netcdf4 lib to extract netcdf via the opendap protocol
# dataset = netCDF4.Dataset('DE0043G.20100101000000.20181114115100.cpc.particle_number_concentration.pm10.1y.1h.DE09L_TSI_CPC_3025.DE09L_cpc.lev2.nc','r','NETCDF4')

# # fetch global attributes from netcdf on the thredds server
# global_attr = dataset.ncattrs()


# for attr in global_attr:
#     #print('{0}: {1}'.format(attr, dataset.getncattr(attr)))
#     if attr=="summary":
#         print(attr)
#         print(dataset.getncattr(attr))
#         sentence = dataset.getncattr(attr)
#         tokens = nltk.word_tokenize(sentence)
#         tagged = nltk.pos_tag(tokens)
#         print(tagged)
# Out:
# Instrument DMPS and variable particle number size distribution:
# Filename: NO0058G.20070218000000.20181205100800.dmps.particle_number_size_distribution.aerosol.3y.1h.NO01L_DMPS_Troll1.NO01L_dmps_DMPS_Troll1.lev2.nc
#
#
# Conventions: CF-1.7, ACDD-1.3
# featureType: timeSeries
# title: Ground based in situ observations of particle_number_size_distribution at Troll (NO0058G) using dmps
# keywords: Troll, NO0058G, number_concentration_of_positive_ions_in_dry_aerosol_particles_in_air, aerosol, GAW-WDCA, particle_number_size_distribution, NILU
# id: NO0058G.20070218000000.20181205100800.dmps.particle_number_size_distribution.aerosol.3y.1h.NO01L_DMPS_Troll1.NO01L_dmps_DMPS_Troll1.lev2.nc
# naming_authority: no.nilu.ebas
# project: GAW-WDCA, NILU
# acknowledgement: []
# license: GAW-WDCA: , NILU: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy).
# summary: Ground based in situ observations of particle_number_size_distribution at Troll (NO0058G) using dmps. These measurements are gathered as a part of the following projects GAW-WDCA, NILU and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in aerosol (number_concentration_of_positive_ions_in_dry_aerosol_particles_in_air)
# summary
# Ground based in situ observations of particle_number_size_distribution at Troll (NO0058G) using dmps. These measurements are gathered as a part of the following projects GAW-WDCA, NILU and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in aerosol (number_concentration_of_positive_ions_in_dry_aerosol_particles_in_air)
#
# ###########
#
# pos tagging:
#
# ###########
#
# source: surface observation
# institution: NO01L, Norwegian Institute for Air Research, NILU, Atmosphere and Climate Department, Instituttveien 18, 2007, Kjeller, Norway
# processing_level: 2: final (Physical parameters, aggregated (if needed), info on variability recommended, quality assured by human inspection. This is the typical EBAS data level meant for dissemination and long term preservation.)
# date_created: 2018-12-05T10:08:00 UTC
# date_metadata_modified: 2018-12-05T10:08:00 UTC
# creator_name: Chris Lunder
# creator_type: person
# creator_email: crl@nilu.no
# creator_institution: "Norwegian Institute for Air Research, Atmosphere and Climate Department, NILU"
# contributor_name: Markus Fiebig
# contributor_role: data submitter
# publisher_type: institution
# publisher_name: NILU - Norwegian Institute for Air Research, ATMOS, EBAS
# publisher_institution: NILU - Norwegian Institute for Air Research, ATMOS, EBAS
# publisher_email: ebas@nilu.no
# publisher_url: http://ebas.nilu.no/
# geospatial_bounds: POINT Z (-72.016667 2.533333 1309.0)
# geospatial_bounds_crs: EPSG:4979
# geospatial_lat_min: -72.016667
# geospatial_lat_max: -72.016667
# geospatial_lon_min: 2.533333
# geospatial_lon_max: 2.533333
# geospatial_vertical_min: 1309.0
# geospatial_vertical_max: 1309.0
# geospatial_vertical_positive: up
# time_coverage_start: 2007-02-18T00:00:00 UTC
# time_coverage_end: 2010-01-01T00:00:00 UTC
# time_coverage_duration: P0002-10-14T00:00:00
# time_coverage_resolution: P0000-00-00T01:00:00
# timezone: UTC
# ebas_metadata: {
#     "Data definition": "EBAS_1.1",
#     "Set type code": "TU",
#     "Timezone": "UTC",
#     "File name": "NO0058G.20070218000000.20181205100800.dmps.particle_number_size_distribution.aerosol.3y.1h.NO01L_DMPS_Troll1.NO01L_dmps_DMPS_Troll1.lev2.nc",
#     "File creation": "20190514072220",
#     "Startdate": "20070218000000",
#     "Revision date": "20181205100800",
#     "Statistics": "arithmetic mean",
#     "Data level": "2",
#     "Period code": "3y",
#     "Resolution code": "1h",
#     "Station code": "NO0058G",
#     "Platform code": "NO0058S",
#     "Station name": "Troll",
#     "Station land use": "Snowfield",
#     "Station setting": "Polar",
#     "Station latitude": "-72.016667",
#     "Station longitude": "2.533333",
#     "Station altitude": "1309.0 m",
#     "Regime": "IMG",
#     "Component": "particle_number_size_distribution",
#     "Unit": "1/cm3",
#     "Matrix": "aerosol",
#     "Laboratory code": "NO01L",
#     "Instrument type": "dmps",
#     "Instrument name": "DMPS_Troll1",
#     "Method ref": "NO01L_dmps_DMPS_Troll1",
#     "Organization": "NO01L, Norwegian Institute for Air Research, NILU, Atmosphere and Climate Department, Instituttveien 18, , 2007, Kjeller, Norway",
#     "Frameworks": "GAW-WDCA NILU",
#     "Originator": "Lunder, Chris, crl@nilu.no, Norwegian Institute for Air Research, NILU, Atmosphere and Climate Department, Instituttveien 18, , 2007, Kjeller, Norway",
#     "Submitter": "Fiebig, Markus, Markus.Fiebig@nilu.no, Norwegian Institute for Air Research, NILU, Atmosphere and Climate Department, Instituttveien 18, , 2007, Kjeller, Norway"
# }
# --- printing raw triples ---
# (rdflib.term.URIRef('http://actrisexample.eu/ns/conventions'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('conventions'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/FileName'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('File name'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Startdate'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Startdate'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/ResolutionCode'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Resolution code'))
# (rdflib.term.BNode('Neab4ea8ea4a84ce786a143d845f982c4'), rdflib.term.URIRef('http://actrisexample.eu/ns/belongsto'), rdflib.term.BNode('N49564e78f198440ab81424699840cba7'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/license'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('license'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/ebas_metadata'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('ebas_metadata'))
# (rdflib.term.URIRef('http://actrisexample/ns/belongsto'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('belongsto'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/title'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('title'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Frameworks'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Frameworks'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_institution'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('publisher_institution'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/date_created'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('date_created'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/DataDefinition'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Data definition'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/LaboratoryCode'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Laboratory code'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('creator_name'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/timezone'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('timezone'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Statistics'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Statistics'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_url'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('publisher_url'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/contributor_role'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('contributor_role'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Submitter'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Submitter'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Originator'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Originator'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/MethodRef'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Method ref'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lat_min'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_lat_min'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/InstrumentName'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Instrument name'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/processing_level'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('processing_level'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/id'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('id'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_email'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('creator_email'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/DataLevel'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Data level'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_start'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('time_coverage_start'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_resolution'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('time_coverage_resolution'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lon_min'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_lon_min'))
# (rdflib.term.BNode('N34d8aea0334f4ca196e28ae42b22a2c0'), rdflib.term.URIRef('http://actrisexample.eu/ns/measures'), rdflib.term.Literal('particle_number_size_distribution'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('publisher_name'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/filename'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('filename'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/StationAltitude'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station altitude'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_vertical_min'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_vertical_min'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_vertical_positive'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_vertical_positive'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lon_max'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_lon_max'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_end'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('time_coverage_end'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/SetTypeCode'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Set type code'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/date_metadata_modified'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('date_metadata_modified'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/FileCreation'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('File creation'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/StationLongitude'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station longitude'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/StationLatitude'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station latitude'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/PeriodCode'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Period code'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/institution'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('institution'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Unit'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Unit'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/naming_authority'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('naming_authority'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Timezone'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Timezone'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/RevisionDate'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Revision date'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/StationName'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station name'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/StationSetting'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station setting'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lat_max'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_lat_max'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_vertical_max'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_vertical_max'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Regime'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Regime'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/PlatformCode'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Platform code'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/keywords'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('keywords'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrumenttype'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Instrument type'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_duration'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('time_coverage_duration'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_bounds'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_bounds'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_bounds_crs'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_bounds_crs'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/acknowledgement'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('acknowledgement'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/project'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('project'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Component'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Component'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Organization'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Organization'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_type'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('creator_type'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/summary'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('summary'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/StationLandUse'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station land use'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_email'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('publisher_email'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_type'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('publisher_type'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/source'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('source'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/featuretype'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('featuretype'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/aerosol'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('aerosol'))
# (rdflib.term.URIRef('http://actrisexample/ns/measures'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('measures'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_institution'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('creator_institution'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/contributor_name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('contributor_name'))
# (rdflib.term.URIRef('http://actrisexample.eu/ns/StationCode'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station code'))
# graph has 77 statements.
