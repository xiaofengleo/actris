# %%
############
## This script read metadata from netCDF file, convert it into rdf triple store, outputs/data.ttl, outputs/data.trig
## Xiaofeng Liao
## 25 Feb, 2020
###############

# %%
pip install netCDF4
pip install rdflib
pip install PyYAML
# Out:
#   File "<ipython-input-1-102418f64239>", line 1
#     pip install netCDF4
#               ^
# SyntaxError: invalid syntax

# %%
import yaml
import netCDF4
import rdflib
from rdflib import Graph, Literal, BNode, Namespace, RDF, URIRef, plugin, ConjunctiveGraph
from rdflib.namespace import DC, FOAF, RDFS
from rdflib.store import Store
import glob

# %%
#import nltk; nltk.download('all')

# %%
ae = Namespace("http://actrisexample.eu/ns/")

vocab = dict()

store = plugin.get('IOMemory', Store)()

g = ConjunctiveGraph(store)
g.bind('envri', 'http://envri.eu/ns/')
g.bind('ae','http://actrisexample.eu/ns/')
g.bind('dcterms', 'http://purl.org/dc/terms/')
#g.bind('foaf', 'http://xmlns.com/foaf/0.1/')
g.bind('skos', 'http://www.w3.org/2004/02/skos/core#')

with open('vocab.yaml', 'r') as f:
    for key, value in yaml.safe_load(f).items():
        v = dict()
        if key == 'Component':
            uris = eval(str(value['uri']))
            for uri in uris:
                #print(uri)
                v['uri'] = URIRef(uri)
                v['label'] = value['label'].replace(' ','_')
                #print(value['label'])
                g.add(( v['uri'], RDFS.label, Literal(v['label']) ))
                g.add( ( v['uri'], URIRef('http://actrisexample.eu/ns/hasvalue'), Literal('aerosol_absorption_coefficient')) )
        else:
            v['uri'] = URIRef(value['uri'])
            #print(v['uri'])
            v['label'] = value['label'].replace(' ','_')
            #print(v['label'])
            vocab[key] = v
            g.add((vocab[key]['uri'], RDFS.label, Literal(vocab[key]['label'])))

print('Instrument filter_absorption_photometer and variable aerosol_absorption_coefficient:\nFilename: DK0025G.20030101000000.20170713083448.filter_absorption_photometer.aerosol_absorption_coefficient.aerosol.12y.1h.US08L_Magee_AE16_SUM.US08L_aethalometer.lev2.nc\n\n')

# use the netcdf4 lib to extract netcdf via the opendap protocol
dataset = netCDF4.Dataset('DK0025G.20030101000000.20170713083448.filter_absorption_photometer.aerosol_absorption_coefficient.aerosol.12y.1h.US08L_Magee_AE16_SUM.US08L_aethalometer.lev2.nc','r','NETCDF4')
# fetch global attributes from netcdf on the thredds server
global_attr = dataset.ncattrs()



## Following lines build nodes for instrument filter_absorption_photometer and its measuring variable aerosol_absorption_coefficient
## and link them with ae.measures
## this should be automated later
filter_absorption_photometer = BNode()
aerosol_absorption_coefficient = BNode()

g.add( (filter_absorption_photometer, RDFS.label, Literal('filter_absorption_photometer') ) )
g.add( (aerosol_absorption_coefficient, RDFS.label, Literal('aerosol_absorption_coefficient') ) )
g.add( (filter_absorption_photometer, ae.measures, aerosol_absorption_coefficient) )



for attr in global_attr:
    if(attr == "ebas_metadata"):
        ebas_metadata = eval(dataset.getncattr(attr))
        for k,v in ebas_metadata.items():
            print('{0}: {1}'.format(k, v))
            if (k !="Component"):
                #uris = eval(str(vocab[k]['uri']))
                #for item in uris:
                #    #print(item)
                #    g.add( ( URIRef(item), vocab['hasvalue']['uri'], Literal(v)) )
            #else:
                g.add( ( URIRef(vocab[k]['uri']), vocab['hasvalue']['uri'], Literal(v.replace(' ','_'))) )
    else:
        print('{0}: {1}'.format(attr, dataset.getncattr(attr)))
        g.add( (URIRef(vocab[attr]['uri']), vocab['hasvalue']['uri'], Literal(str(dataset.getncattr(attr)).replace(' ','_'))) )

print("\n--- printing raw triples ---")
for s, p, o in g:
    print('\n')
    print((s, p, o))
    

print("\n graph has %s statements." % len(g))

g.serialize(destination='outputs/data.ttl', format='ttl')
g.serialize(destination='outputs/data.trig', format='trig')
# Out:
# Instrument filter_absorption_photometer and variable aerosol_absorption_coefficient:
# Filename: DK0025G.20030101000000.20170713083448.filter_absorption_photometer.aerosol_absorption_coefficient.aerosol.12y.1h.US08L_Magee_AE16_SUM.US08L_aethalometer.lev2.nc
#
#
# Conventions: CF-1.7, ACDD-1.3
# featureType: timeSeries
# title: Ground based in situ observations of aerosol_absorption_coefficient at Summit (DK0025G) using filter_absorption_photometer
# keywords: NOAA-ESRL, DK0025G, aerosol_absorption_coefficient, Summit, aerosol, GAW-WDCA, volume_absorption_coefficient_in_air_due_to_dried_aerosol_particles
# id: DK0025G.20030101000000.20170713083448.filter_absorption_photometer.aerosol_absorption_coefficient.aerosol.12y.1h.US08L_Magee_AE16_SUM.US08L_aethalometer.lev2.nc
# naming_authority: no.nilu.ebas
# project: NOAA-ESRL, GAW-WDCA
# acknowledgement: Request acknowledgement details from data originator
# license: NOAA-ESRL: , GAW-WDCA:
# summary: Ground based in situ observations of aerosol_absorption_coefficient at Summit (DK0025G) using filter_absorption_photometer. These measurements are gathered as a part of the following projects NOAA-ESRL, GAW-WDCA and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: aerosol_absorption_coefficient in aerosol (volume_absorption_coefficient_in_air_due_to_dried_aerosol_particles)
# source: surface observation
# institution: US08L, National Science Foundation, NSF/OPP, Office of Polar Programs, NSF/OPP, 4201 Wilson Boulevard, , 22230, Arlington VA, USA
# processing_level: 2: final (Physical parameters, aggregated (if needed), info on variability recommended, quality assured by human inspection. This is the typical EBAS data level meant for dissemination and long term preservation.)
# date_created: 2017-07-13T08:34:48 UTC
# date_metadata_modified: 2017-07-13T08:34:48 UTC
# creator_name: Mike Bergin, John Ogren
# creator_type: person
# creator_email: , John.A.Ogren@noaa.gov
# creator_institution: , "National Oceanic and Atmospheric Administration/Earth System Research Laboratory/Global Monitoring Division, NOAA/ESRL/GMD"
# contributor_name: Mike Bergin
# contributor_role: data submitter
# publisher_type: institution
# publisher_name: NILU - Norwegian Institute for Air Research, ATMOS, EBAS
# publisher_institution: NILU - Norwegian Institute for Air Research, ATMOS, EBAS
# publisher_email: ebas@nilu.no
# publisher_url: http://ebas.nilu.no/
# geospatial_bounds: POINT Z (72.5800018311 -38.4799995422 3238.0)
# geospatial_bounds_crs: EPSG:4979
# geospatial_lat_min: 72.5800018311
# geospatial_lat_max: 72.5800018311
# geospatial_lon_min: -38.4799995422
# geospatial_lon_max: -38.4799995422
# geospatial_vertical_min: 3238.0
# geospatial_vertical_max: 3238.0
# geospatial_vertical_positive: up
# time_coverage_start: 2003-01-01T00:00:00 UTC
# time_coverage_end: 2015-01-01T00:00:00 UTC
# time_coverage_duration: P0012-00-00T00:00:00
# time_coverage_resolution: P0000-00-00T01:00:00
# timezone: UTC
# Data definition: EBAS_1.1
# Set type code: TU
# Timezone: UTC
# File name: DK0025G.20030101000000.20170713083448.filter_absorption_photometer.aerosol_absorption_coefficient.aerosol.12y.1h.US08L_Magee_AE16_SUM.US08L_aethalometer.lev2.nc
# File creation: 20190513125103
# Startdate: 20030101000000
# Revision date: 20170713083448
# Version: 1
# Data level: 2
# Period code: 12y
# Resolution code: 1h
# Sample duration: 1h
# Orig. time res.: 1mn
# Station code: DK0025G
# Platform code: DK0025S
# Station name: Summit
# Station WDCA-ID: GAWADK__SUM
# Station GAW-ID: SUM
# Station GAW-Name: Summit
# Station land use: Snowfield
# Station setting: Polar
# Station GAW type: G
# Station WMO region: 6
# Station latitude: 72.5800018311
# Station longitude: -38.4799995422
# Station altitude: 3238.0 m
# Regime: IMG
# Component: aerosol_absorption_coefficient
# Unit: 1/Mm
# Matrix: aerosol
# Laboratory code: US08L
# Instrument type: filter_absorption_photometer
# Instrument name: Magee_AE16_SUM
# Instrument manufacturer: Magee
# Instrument model: AE16
# Instrument serial number: 175
# Method ref: US08L_aethalometer
# Standard method: SOP=GAW227
# Inlet type: Downward-facing tube
# Humidity/temperature control: None
# Volume std. temperature: 273.15 K
# Volume std. pressure: 1013.25 hPa
# Detection limit: 0.047429 1/Mm
# Detection limit expl.: Determined by instrument noise characteristics, no detection limit flag used
# Measurement uncertainty: 25.0 %
# Measurement uncertainty expl.: Intercomparisons with thermo-optical analysis have shown an uncertainty of a faktor 2 regardless specific absorption cross-section assumed.
# Zero/negative values code: Zero/negative possible
# Zero/negative values: Zero and neg. values may appear due to statistical variations at very low concentrations
# Organization: US08L, "National Science Foundation, NSF/OPP, Office of Polar Programs", NSF/OPP, , "4201 Wilson Boulevard, , 22230, Arlington VA, USA", , , ,
# Frameworks: GAW-WDCA NOAA-ESRL
# Originator: Ogren, John, John.A.Ogren@noaa.gov, National Oceanic and Atmospheric Administration/Earth System Research Laboratory/Global Monitoring Division, NOAA/ESRL/GMD, , 325 Broadway, , 80305, "Boulder, CO", USA
# Submitter: Bergin, Mike, , , , , , , , ,
# Acknowledgement: Request acknowledgement details from data originator
# Comment: calibration factor / mean ratio=1.0; sample_spot_area=5e-5 m2; Sigma=16.0. Raw EBC data as reported by instrument, which is a factor of 2.0 higher than the value calculated from the reported intensities. EBC should be calculated from intensities.
#
# --- printing raw triples ---
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Volume_std._temperature'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Volume_std._temperature'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_start'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('time_coverage_start'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/date_created'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('2017-07-13T08:34:48_UTC'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_vertical_max'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('3238.0'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Component'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Component'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/timezone'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('timezone'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Conventions'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('CF-1.7,_ACDD-1.3'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_land_use'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_land_use'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/date_metadata_modified'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('date_metadata_modified'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_code'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_code'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_name'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Mike_Bergin,_John_Ogren'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Laboratory_code'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Laboratory_code'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Method_ref'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Method_ref'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/summary'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Ground_based_in_situ_observations_of_aerosol_absorption_coefficient_at_Summit_(DK0025G)_using_filter_absorption_photometer._These_measurements_are_gathered_as_a_part_of_the_following_projects_NOAA-ESRL,_GAW-WDCA_and_they_are_stored_in_the_EBAS_database_(http://ebas.nilu.no/)._Parameters_measured_are:_aerosol_absorption_coefficient_in_aerosol_(volume_absorption_coefficient_in_air_due_to_dried_aerosol_particles)'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/contributor_role'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('data_submitter'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/featureType'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('timeSeries'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_code'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('DK0025G'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_bounds'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_bounds'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Humidity/temperature_control'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Humidity/temperature_control'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/timezone'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('UTC'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Detection_limit'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('0.047429_1/Mm'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_GAW_type'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('G'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/naming_authority'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('no.nilu.ebas'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/File_name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('File_name'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/contributor_role'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('contributor_role'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/source'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('surface_observation'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/processing_level'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('processing_level'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_email'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('ebas@nilu.no'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_url'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('publisher_url'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_GAW-Name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_GAW-Name'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrument_name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Instrument_name'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Volume_std._pressure'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('1013.25_hPa'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Submitter'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Bergin,_Mike,_,_,_,_,_,_,_,_,_'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_vertical_max'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_vertical_max'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Zero/negative_values_code'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Zero/negative_values_code'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Laboratory_code'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('US08L'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/license'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('NOAA-ESRL:_,_GAW-WDCA:_'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_vertical_min'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_vertical_min'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Inlet_type'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Inlet_type'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_duration'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('P0012-00-00T00:00:00'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_setting'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_setting'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Data_level'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('2'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Zero/negative_values'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Zero_and_neg._values_may_appear_due_to_statistical_variations_at_very_low_concentrations'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_type'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('person'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_altitude'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_altitude'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Data_level'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Data_level'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrument_serial_number'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('175'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/acknowledgement'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Request_acknowledgement_details_from_data_originator'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_type'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('publisher_type'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/File_creation'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('File_creation'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Conventions'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Conventions'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_name'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Summit'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Sample_duration'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('1h'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrument_type'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Instrument_type'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Regime'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('IMG'))
#
#
# (rdflib.term.URIRef('http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Component'))
#
#
# (rdflib.term.URIRef('http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/316'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('aerosol_absorption_coefficient'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_name'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/institution'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('US08L,_National_Science_Foundation,_NSF/OPP,_Office_of_Polar_Programs,_NSF/OPP,_4201_Wilson_Boulevard,_,_22230,_Arlington_VA,_USA'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_latitude'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_latitude'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/institution'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('institution'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Method_ref'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('US08L_aethalometer'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Version'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('1'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_resolution'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('P0000-00-00T01:00:00'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/processing_level'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('2:_final_(Physical_parameters,_aggregated_(if_needed),_info_on_variability_recommended,_quality_assured_by_human_inspection._This_is_the_typical_EBAS_data_level_meant_for_dissemination_and_long_term_preservation.)'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Measurement_uncertainty'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('25.0_%'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lat_max'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('72.5800018311'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Matrix'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('aerosol'))
#
#
# (rdflib.term.BNode('N2b2e959c578e46d0b36e87e787d2d5aa'), rdflib.term.URIRef('http://actrisexample.eu/ns/measures'), rdflib.term.BNode('N77e25fa6cb8d40da92d66685be5360fe'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_bounds'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('POINT_Z_(72.5800018311_-38.4799995422_3238.0)'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrument_manufacturer'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Instrument_manufacturer'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Frameworks'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Frameworks'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Unit'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('1/Mm'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrument_manufacturer'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Magee'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_type'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('creator_type'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Resolution_code'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('1h'))
#
#
# (rdflib.term.URIRef('http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/316'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Component'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_WMO_region'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_WMO_region'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Originator'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Ogren,_John,_John.A.Ogren@noaa.gov,_National_Oceanic_and_Atmospheric_Administration/Earth_System_Research_Laboratory/Global_Monitoring_Division,_NOAA/ESRL/GMD,_,_325_Broadway,_,_80305,_"Boulder,_CO",_USA'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Revision_date'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('20170713083448'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Measurement_uncertainty_expl.'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Intercomparisons_with_thermo-optical_analysis_have_shown_an_uncertainty_of_a_faktor_2_regardless_specific_absorption_cross-section_assumed.'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_institution'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('NILU_-_Norwegian_Institute_for_Air_Research,_ATMOS,_EBAS'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Volume_std._temperature'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('273.15_K'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/featureType'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('featureType'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/NULL'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('NULL'))
#
#
# (rdflib.term.URIRef('http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('aerosol_absorption_coefficient'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Platform_code'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Platform_code'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Volume_std._pressure'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Volume_std._pressure'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Measurement_uncertainty_expl.'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Measurement_uncertainty_expl.'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_bounds_crs'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('EPSG:4979'))
#
#
# (rdflib.term.URIRef('http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/318'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('aerosol_absorption_coefficient'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_GAW-ID'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('SUM'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Timezone'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Timezone'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Zero/negative_values_code'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Zero/negative_possible'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_end'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('time_coverage_end'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrument_type'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('filter_absorption_photometer'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/date_metadata_modified'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('2017-07-13T08:34:48_UTC'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrument_model'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Instrument_model'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/project'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('NOAA-ESRL,_GAW-WDCA'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/title'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('title'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Orig._time_res.'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('1mn'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_resolution'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('time_coverage_resolution'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Orig._time_res.'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Orig._time_res.'))
#
#
# (rdflib.term.BNode('N77e25fa6cb8d40da92d66685be5360fe'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('aerosol_absorption_coefficient'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Set_type_code'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('TU'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('creator_name'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/acknowledgement'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('acknowledgement'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/source'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('source'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_WDCA-ID'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('GAWADK__SUM'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/contributor_name'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Mike_Bergin'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/summary'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('summary'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lat_max'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_lat_max'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('hasvalue'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Standard_method'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('SOP=GAW227'))
#
#
# (rdflib.term.URIRef('http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/318'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Component'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Revision_date'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Revision_date'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Detection_limit_expl.'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Detection_limit_expl.'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Zero/negative_values'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Zero/negative_values'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Acknowledgement'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Acknowledgement'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lon_min'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_lon_min'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_longitude'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_longitude'))
#
#
# (rdflib.term.BNode('N2b2e959c578e46d0b36e87e787d2d5aa'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('filter_absorption_photometer'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Humidity/temperature_control'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('None'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_vertical_min'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('3238.0'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Startdate'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Startdate'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_email'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('publisher_email'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_WMO_region'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('6'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Submitter'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Submitter'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_setting'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Polar'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/project'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('project'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_vertical_positive'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_vertical_positive'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/NULL'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('None'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Component'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('aerosol_absorption_coefficient'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Measurement_uncertainty'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Measurement_uncertainty'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('publisher_name'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_institution'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal(',_"National_Oceanic_and_Atmospheric_Administration/Earth_System_Research_Laboratory/Global_Monitoring_Division,_NOAA/ESRL/GMD"'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_GAW-ID'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_GAW-ID'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_institution'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('publisher_institution'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/keywords'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('keywords'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/id'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('id'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Frameworks'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('GAW-WDCA_NOAA-ESRL'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_GAW_type'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_GAW_type'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Sample_duration'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Sample_duration'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_email'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('creator_email'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_type'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('institution'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_name'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('NILU_-_Norwegian_Institute_for_Air_Research,_ATMOS,_EBAS'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Acknowledgement'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Request_acknowledgement_details_from_data_originator'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_WDCA-ID'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Station_WDCA-ID'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_vertical_positive'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('up'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/naming_authority'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('naming_authority'))
#
#
# (rdflib.term.URIRef('http://vocab.nerc.ac.uk/collection/P07/current/3TUNI9CM/'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Component'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Period_code'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Period_code'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Unit'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Unit'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Period_code'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('12y'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrument_model'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('AE16'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/date_created'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('date_created'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/id'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('DK0025G.20030101000000.20170713083448.filter_absorption_photometer.aerosol_absorption_coefficient.aerosol.12y.1h.US08L_Magee_AE16_SUM.US08L_aethalometer.lev2.nc'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lon_max'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('-38.4799995422'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_GAW-Name'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Summit'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/keywords'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('NOAA-ESRL,_DK0025G,_aerosol_absorption_coefficient,_Summit,_aerosol,_GAW-WDCA,_volume_absorption_coefficient_in_air_due_to_dried_aerosol_particles'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Data_definition'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('EBAS_1.1'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Resolution_code'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Resolution_code'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/measures'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('measures'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Organization'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Organization'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_bounds_crs'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_bounds_crs'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrument_serial_number'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Instrument_serial_number'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_land_use'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Snowfield'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lon_min'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('-38.4799995422'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_start'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('2003-01-01T00:00:00_UTC'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lat_min'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_lat_min'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Regime'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Regime'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Detection_limit'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Detection_limit'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Originator'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Originator'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Startdate'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('20030101000000'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Platform_code'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('DK0025S'))
#
#
# (rdflib.term.URIRef('http://vocab.nerc.ac.uk/collection/P07/current/3TUNI9CM/'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('aerosol_absorption_coefficient'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lon_max'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('geospatial_lon_max'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_email'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal(',_John.A.Ogren@noaa.gov'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Inlet_type'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Downward-facing_tube'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Data_definition'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Data_definition'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/title'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Ground_based_in_situ_observations_of_aerosol_absorption_coefficient_at_Summit_(DK0025G)_using_filter_absorption_photometer'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_latitude'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('72.5800018311'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_altitude'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('3238.0_m'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Organization'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('US08L,_"National_Science_Foundation,_NSF/OPP,_Office_of_Polar_Programs",_NSF/OPP,_,_"4201_Wilson_Boulevard,_,_22230,_Arlington_VA,_USA",_,_,_,_'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Instrument_name'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Magee_AE16_SUM'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_duration'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('time_coverage_duration'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Comment'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('calibration_factor_/_mean_ratio=1.0;_sample_spot_area=5e-5_m2;_Sigma=16.0._Raw_EBC_data_as_reported_by_instrument,_which_is_a_factor_of_2.0_higher_than_the_value_calculated_from_the_reported_intensities._EBC_should_be_calculated_from_intensities.'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Timezone'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('UTC'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/creator_institution'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('creator_institution'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/geospatial_lat_min'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('72.5800018311'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Station_longitude'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('-38.4799995422'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/publisher_url'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('http://ebas.nilu.no/'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Standard_method'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Standard_method'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Set_type_code'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Set_type_code'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Comment'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Comment'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/File_name'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('DK0025G.20030101000000.20170713083448.filter_absorption_photometer.aerosol_absorption_coefficient.aerosol.12y.1h.US08L_Magee_AE16_SUM.US08L_aethalometer.lev2.nc'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Detection_limit_expl.'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('Determined_by_instrument_noise_characteristics,_no_detection_limit_flag_used'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/File_creation'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('20190513125103'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Version'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Version'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/Matrix'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('Matrix'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/contributor_name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('contributor_name'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/time_coverage_end'), rdflib.term.URIRef('http://actrisexample.eu/ns/hasvalue'), rdflib.term.Literal('2015-01-01T00:00:00_UTC'))
#
#
# (rdflib.term.URIRef('http://actrisexample.eu/ns/license'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'), rdflib.term.Literal('license'))
#
#  graph has 203 statements.
