# %%
################
# This script provides some example sparql queries towards the triple store generated, 
# for example, the data.ttl or data.trig
################

# %%
pip install openpyxl==2.6.4
# Out:
# Collecting openpyxl==2.6.4
#   Downloading https://files.pythonhosted.org/packages/d6/26/eb28e975b7a37aad38d7ec4f7a0f652bdee6ecf36e6bd06f473c5af9b87b/openpyxl-2.6.4.tar.gz (173kB)
#     100% |████████████████████████████████| 174kB 4.6MB/s ta 0:00:01
# Collecting jdcal (from openpyxl==2.6.4)
#   Downloading https://files.pythonhosted.org/packages/f0/da/572cbc0bc582390480bbd7c4e93d14dc46079778ed915b505dc494b37c57/jdcal-1.4.1-py2.py3-none-any.whl
# Collecting et_xmlfile (from openpyxl==2.6.4)
#   Downloading https://files.pythonhosted.org/packages/22/28/a99c42aea746e18382ad9fb36f64c1c1f04216f41797f2f0fa567da11388/et_xmlfile-1.0.1.tar.gz
# Building wheels for collected packages: openpyxl, et-xmlfile
#   Building wheel for openpyxl (setup.py) ... done
#   Stored in directory: /Users/admin/Library/Caches/pip/wheels/58/1d/e3/7c7ee57db55ac00dd5c4632287d8401cdd08ed59c965306f9c
#   Building wheel for et-xmlfile (setup.py) ... done
#   Stored in directory: /Users/admin/Library/Caches/pip/wheels/2a/77/35/0da0965a057698121fc7d8c5a7a9955cdbfb3cc4e2423cad39
# Successfully built openpyxl et-xmlfile
# Installing collected packages: jdcal, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.0.1 jdcal-1.4.1 openpyxl-2.6.4
# You are using pip version 19.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import io
import collections
import pandas as pd
import matplotlib.pyplot as plt
from rdflib import ConjunctiveGraph
from rdflib.plugins.sparql.results.csvresults import CSVResultSerializer

pd.set_option('display.max_colwidth', 200)

if not os.path.exists('outputs'):
    os.makedirs('outputs')
    
g = ConjunctiveGraph()
g.parse('data.ttl', format='trig')

def query(q):
    serializer = CSVResultSerializer(g.query(q))
    output = io.BytesIO()
    serializer.serialize(output)
    return pd.read_csv(io.StringIO(output.getvalue().decode('utf-8')), encoding='utf-8')
    
def write(df, fn):
    df.to_excel('outputs/{}'.format(fn), encoding='utf-8')

# %%
#display all triples
q = query("""
prefix ae: <http://actrisexample.eu/ns/>
prefix dcterms: <http://purl.org/dc/terms/>
prefix envri: <http://envri.eu/ns/>
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix skos: <http://www.w3.org/2004/02/skos/core#>
prefix xml: <http://www.w3.org/XML/1998/namespace>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?subject ?property ?object
WHERE {
 # ?subject ?property ?object.
}
""")

display(q)
#write(q, 'output1.xlsx')
# Out:
#                                                       subject  \
# 0                  http://actrisexample.eu/ns/Laboratory_code
# 1                 http://actrisexample.eu/ns/naming_authority
# 2    http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/318
# 3                http://actrisexample.eu/ns/geospatial_bounds
# 4                  http://actrisexample.eu/ns/Data_definition
# 5                        http://actrisexample.eu/ns/File_name
# 6                    http://actrisexample.eu/ns/File_creation
# 7            http://actrisexample.eu/ns/publisher_institution
# 8                     http://actrisexample.eu/ns/date_created
# 9               http://actrisexample.eu/ns/geospatial_lon_min
# 10                http://actrisexample.eu/ns/Station_GAW-Name
# 11                 http://actrisexample.eu/ns/Detection_limit
# 12                        http://actrisexample.eu/ns/Timezone
# 13                         http://actrisexample.eu/ns/Comment
# 14                   http://actrisexample.eu/ns/Set_type_code
# 15            http://actrisexample.eu/ns/Zero/negative_values
# 16                   http://actrisexample.eu/ns/publisher_url
# 17                      http://actrisexample.eu/ns/Method_ref
# 18                          http://actrisexample.eu/ns/source
# 19                       http://actrisexample.eu/ns/Startdate
# 20                 http://actrisexample.eu/ns/Station_setting
# 21              http://actrisexample.eu/ns/geospatial_lon_max
# 22            http://actrisexample.eu/ns/Volume_std._pressure
# 23                            http://actrisexample.eu/ns/Unit
# 24                    http://actrisexample.eu/ns/creator_name
# 25                      http://actrisexample.eu/ns/Data_level
# 26                http://actrisexample.eu/ns/processing_level
# 27   http://actrisexample.eu/ns/Measurement_uncertainty_expl.
# 28                 http://actrisexample.eu/ns/Detection_limit
# 29                           http://actrisexample.eu/ns/title
# ..                                                        ...
# 169                 http://actrisexample.eu/ns/publisher_type
# 170  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/318
# 171                http://actrisexample.eu/ns/Station_WDCA-ID
# 172                        http://actrisexample.eu/ns/Version
# 173                http://actrisexample.eu/ns/Instrument_name
# 174       http://actrisexample.eu/ns/time_coverage_resolution
# 175                   http://actrisexample.eu/ns/date_created
# 176   http://actrisexample.eu/ns/Humidity/temperature_control
# 177                http://actrisexample.eu/ns/Resolution_code
# 178                  http://actrisexample.eu/ns/publisher_url
# 179        http://actrisexample.eu/ns/Measurement_uncertainty
# 180                      http://actrisexample.eu/ns/Component
# 181      http://actrisexample.eu/ns/Zero/negative_values_code
# 182               http://actrisexample.eu/ns/contributor_role
# 183                    http://actrisexample.eu/ns/Period_code
# 184                http://actrisexample.eu/ns/Acknowledgement
# 185             http://actrisexample.eu/ns/Station_WMO_region
# 186                   http://actrisexample.eu/ns/Station_code
# 187   http://actrisexample.eu/ns/geospatial_vertical_positive
# 188                   http://actrisexample.eu/ns/creator_type
# 189                        http://actrisexample.eu/ns/Version
# 190        http://actrisexample.eu/ns/geospatial_vertical_max
# 191                    http://actrisexample.eu/ns/Period_code
# 192   http://actrisexample.eu/ns/geospatial_vertical_positive
# 193                             http://actrisexample.eu/ns/id
# 194                   http://actrisexample.eu/ns/creator_name
# 195               http://actrisexample.eu/ns/Station_latitude
# 196  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317
# 197           http://actrisexample.eu/ns/Volume_std._pressure
# 198        http://actrisexample.eu/ns/geospatial_vertical_min
#
#                                        property  \
# 0    http://www.w3.org/2000/01/rdf-schema#label
# 1    http://www.w3.org/2000/01/rdf-schema#label
# 2    http://www.w3.org/2000/01/rdf-schema#label
# 3           http://actrisexample.eu/ns/hasvalue
# 4    http://www.w3.org/2000/01/rdf-schema#label
# 5    http://www.w3.org/2000/01/rdf-schema#label
# 6    http://www.w3.org/2000/01/rdf-schema#label
# 7           http://actrisexample.eu/ns/hasvalue
# 8    http://www.w3.org/2000/01/rdf-schema#label
# 9           http://actrisexample.eu/ns/hasvalue
# 10   http://www.w3.org/2000/01/rdf-schema#label
# 11   http://www.w3.org/2000/01/rdf-schema#label
# 12          http://actrisexample.eu/ns/hasvalue
# 13   http://www.w3.org/2000/01/rdf-schema#label
# 14   http://www.w3.org/2000/01/rdf-schema#label
# 15   http://www.w3.org/2000/01/rdf-schema#label
# 16          http://actrisexample.eu/ns/hasvalue
# 17          http://actrisexample.eu/ns/hasvalue
# 18   http://www.w3.org/2000/01/rdf-schema#label
# 19   http://www.w3.org/2000/01/rdf-schema#label
# 20   http://www.w3.org/2000/01/rdf-schema#label
# 21          http://actrisexample.eu/ns/hasvalue
# 22          http://actrisexample.eu/ns/hasvalue
# 23          http://actrisexample.eu/ns/hasvalue
# 24   http://www.w3.org/2000/01/rdf-schema#label
# 25   http://www.w3.org/2000/01/rdf-schema#label
# 26   http://www.w3.org/2000/01/rdf-schema#label
# 27   http://www.w3.org/2000/01/rdf-schema#label
# 28          http://actrisexample.eu/ns/hasvalue
# 29   http://www.w3.org/2000/01/rdf-schema#label
# ..                                          ...
# 169         http://actrisexample.eu/ns/hasvalue
# 170         http://actrisexample.eu/ns/hasvalue
# 171         http://actrisexample.eu/ns/hasvalue
# 172  http://www.w3.org/2000/01/rdf-schema#label
# 173  http://www.w3.org/2000/01/rdf-schema#label
# 174         http://actrisexample.eu/ns/hasvalue
# 175         http://actrisexample.eu/ns/hasvalue
# 176         http://actrisexample.eu/ns/hasvalue
# 177         http://actrisexample.eu/ns/hasvalue
# 178  http://www.w3.org/2000/01/rdf-schema#label
# 179         http://actrisexample.eu/ns/hasvalue
# 180  http://www.w3.org/2000/01/rdf-schema#label
# 181  http://www.w3.org/2000/01/rdf-schema#label
# 182  http://www.w3.org/2000/01/rdf-schema#label
# 183         http://actrisexample.eu/ns/hasvalue
# 184  http://www.w3.org/2000/01/rdf-schema#label
# 185  http://www.w3.org/2000/01/rdf-schema#label
# 186  http://www.w3.org/2000/01/rdf-schema#label
# 187         http://actrisexample.eu/ns/hasvalue
# 188         http://actrisexample.eu/ns/hasvalue
# 189         http://actrisexample.eu/ns/hasvalue
# 190  http://www.w3.org/2000/01/rdf-schema#label
# 191  http://www.w3.org/2000/01/rdf-schema#label
# 192  http://www.w3.org/2000/01/rdf-schema#label
# 193  http://www.w3.org/2000/01/rdf-schema#label
# 194         http://actrisexample.eu/ns/hasvalue
# 195  http://www.w3.org/2000/01/rdf-schema#label
# 196  http://www.w3.org/2000/01/rdf-schema#label
# 197  http://www.w3.org/2000/01/rdf-schema#label
# 198  http://www.w3.org/2000/01/rdf-schema#label
#
#                                                        object
# 0                                             Laboratory_code
# 1                                            naming_authority
# 2                                                   Component
# 3               POINT_Z_(72.5800018311_-38.4799995422_3238.0)
# 4                                             Data_definition
# 5                                                   File_name
# 6                                               File_creation
# 7    NILU_-_Norwegian_Institute_for_Air_Research,_ATMOS,_EBAS
# 8                                                date_created
# 9                                              -38.4799995422
# 10                                           Station_GAW-Name
# 11                                            Detection_limit
# 12                                                        UTC
# 13                                                    Comment
# 14                                              Set_type_code
# 15                                       Zero/negative_values
# 16                                       http://ebas.nilu.no/
# 17                                         US08L_aethalometer
# 18                                                     source
# 19                                                  Startdate
# 20                                            Station_setting
# 21                                             -38.4799995422
# 22                                                1013.25_hPa
# 23                                                       1/Mm
# 24                                               creator_name
# 25                                                 Data_level
# 26                                           processing_level
# 27                              Measurement_uncertainty_expl.
# 28                                              0.047429_1/Mm
# 29                                                      title
# ..                                                        ...
# 169                                               institution
# 170                            aerosol_absorption_coefficient
# 171                                               GAWADK__SUM
# 172                                                   Version
# 173                                           Instrument_name
# 174                                      P0000-00-00T01:00:00
# 175                                   2017-07-13T08:34:48_UTC
# 176                                                      None
# 177                                                        1h
# 178                                             publisher_url
# 179                                                    25.0_%
# 180                                                 Component
# 181                                 Zero/negative_values_code
# 182                                          contributor_role
# 183                                                       12y
# 184                                           Acknowledgement
# 185                                        Station_WMO_region
# 186                                              Station_code
# 187                                                        up
# 188                                                    person
# 189                                                         1
# 190                                   geospatial_vertical_max
# 191                                               Period_code
# 192                              geospatial_vertical_positive
# 193                                                        id
# 194                                   Mike_Bergin,_John_Ogren
# 195                                          Station_latitude
# 196                                                 Component
# 197                                      Volume_std._pressure
# 198                                   geospatial_vertical_min
#
# [199 rows x 3 columns]

# %%
#display triples has value 'aerosol_absorption_coefficient'
q = query("""
prefix ae: <http://actrisexample.eu/ns/>
prefix dcterms: <http://purl.org/dc/terms/>
prefix envri: <http://envri.eu/ns/>
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix skos: <http://www.w3.org/2004/02/skos/core#>
prefix xml: <http://www.w3.org/XML/1998/namespace>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>


SELECT ?subject ?property ?object
WHERE {
VALUES ?object { 'aerosol_absorption_coefficient' }

 # ?subject ?property ?object .
 }
""")

display(q)
# Out:
#                                                     subject  \
# 0  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/318
# 1  http://vocab.nerc.ac.uk/collection/P07/current/3TUNI9CM/
# 2  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/316
# 3  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317
# 4                      http://actrisexample.eu/ns/Component
#
#                               property                          object
# 0  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 1  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 2  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 3  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 4  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient

# %%
#display triples has value 'aerosol_absorption_coefficient'
#in current context, the result is the same with ab
q = query("""
prefix ae: <http://actrisexample.eu/ns/>
prefix dcterms: <http://purl.org/dc/terms/>
prefix envri: <http://envri.eu/ns/>
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix skos: <http://www.w3.org/2004/02/skos/core#>
prefix xml: <http://www.w3.org/XML/1998/namespace>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>


SELECT ?subject ?property ?object
WHERE {
VALUES ?object { 'aerosol_absorption_coefficient' }
VALUES ?property {ae:hasvalue}
#VALUES ?subject {<http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317>}
 # ?subject ?property ?object .
 }
""")

display(q)
# Out:
#                                                     subject  \
# 0  http://vocab.nerc.ac.uk/collection/P07/current/3TUNI9CM/
# 1  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/316
# 2  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/318
# 3  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317
# 4                      http://actrisexample.eu/ns/Component
#
#                               property                          object
# 0  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 1  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 2  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 3  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 4  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
