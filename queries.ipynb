# %%
################
# This script provides some example sparql queries towards the triple store generated, 
# for example, the data.ttl or data.trig
################

# %%
pip install openpyxl==2.6.4
# Out:
# Collecting openpyxl==2.6.4
#   Downloading https://files.pythonhosted.org/packages/d6/26/eb28e975b7a37aad38d7ec4f7a0f652bdee6ecf36e6bd06f473c5af9b87b/openpyxl-2.6.4.tar.gz (173kB)
#     100% |████████████████████████████████| 174kB 4.6MB/s ta 0:00:01
# Collecting jdcal (from openpyxl==2.6.4)
#   Downloading https://files.pythonhosted.org/packages/f0/da/572cbc0bc582390480bbd7c4e93d14dc46079778ed915b505dc494b37c57/jdcal-1.4.1-py2.py3-none-any.whl
# Collecting et_xmlfile (from openpyxl==2.6.4)
#   Downloading https://files.pythonhosted.org/packages/22/28/a99c42aea746e18382ad9fb36f64c1c1f04216f41797f2f0fa567da11388/et_xmlfile-1.0.1.tar.gz
# Building wheels for collected packages: openpyxl, et-xmlfile
#   Building wheel for openpyxl (setup.py) ... done
#   Stored in directory: /Users/admin/Library/Caches/pip/wheels/58/1d/e3/7c7ee57db55ac00dd5c4632287d8401cdd08ed59c965306f9c
#   Building wheel for et-xmlfile (setup.py) ... done
#   Stored in directory: /Users/admin/Library/Caches/pip/wheels/2a/77/35/0da0965a057698121fc7d8c5a7a9955cdbfb3cc4e2423cad39
# Successfully built openpyxl et-xmlfile
# Installing collected packages: jdcal, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.0.1 jdcal-1.4.1 openpyxl-2.6.4
# You are using pip version 19.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import io
import collections
import pandas as pd
import matplotlib.pyplot as plt
from rdflib import ConjunctiveGraph
from rdflib.plugins.sparql.results.csvresults import CSVResultSerializer

pd.set_option('display.max_colwidth', 200)

if not os.path.exists('outputs'):
    os.makedirs('outputs')
    
g = ConjunctiveGraph()
g.parse('data.ttl', format='trig')

def query(q):
    serializer = CSVResultSerializer(g.query(q))
    output = io.BytesIO()
    serializer.serialize(output)
    return pd.read_csv(io.StringIO(output.getvalue().decode('utf-8')), encoding='utf-8')
    
def write(df, fn):
    df.to_excel('outputs/{}'.format(fn), encoding='utf-8')

# %%
#display all triples
q = query("""
prefix ae: <http://actrisexample.eu/ns/>
prefix dcterms: <http://purl.org/dc/terms/>
prefix envri: <http://envri.eu/ns/>
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix skos: <http://www.w3.org/2004/02/skos/core#>
prefix xml: <http://www.w3.org/XML/1998/namespace>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?subject ?property ?object
WHERE {
 # ?subject ?property ?object.
}
""")

display(q)
#write(q, 'output1.xlsx')
# Out:
#                                                       subject  \
# 0                      http://actrisexample.eu/ns/featureType
# 1                 http://actrisexample.eu/ns/Station_GAW_type
# 2                            http://actrisexample.eu/ns/title
# 3              http://actrisexample.eu/ns/time_coverage_start
# 4                  http://actrisexample.eu/ns/Sample_duration
# 5                  http://actrisexample.eu/ns/Acknowledgement
# 6              http://actrisexample.eu/ns/creator_institution
# 7                  http://actrisexample.eu/ns/Standard_method
# 8                  http://actrisexample.eu/ns/Detection_limit
# 9                 http://actrisexample.eu/ns/Station_altitude
# 10         http://actrisexample.eu/ns/Instrument_manufacturer
# 11                 http://actrisexample.eu/ns/Instrument_type
# 12                http://actrisexample.eu/ns/Station_land_use
# 13   http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317
# 14                    http://actrisexample.eu/ns/creator_name
# 15                 http://actrisexample.eu/ns/Resolution_code
# 16                        http://actrisexample.eu/ns/measures
# 17                http://actrisexample.eu/ns/Instrument_model
# 18                http://actrisexample.eu/ns/Station_GAW_type
# 19                http://actrisexample.eu/ns/Station_latitude
# 20                   http://actrisexample.eu/ns/Set_type_code
# 21                    http://actrisexample.eu/ns/date_created
# 22                 http://actrisexample.eu/ns/Instrument_name
# 23                        http://actrisexample.eu/ns/timezone
# 24              http://actrisexample.eu/ns/geospatial_lon_max
# 25                 http://actrisexample.eu/ns/Data_definition
# 26                          http://actrisexample.eu/ns/Regime
# 27                         http://actrisexample.eu/ns/Version
# 28                        http://actrisexample.eu/ns/Timezone
# 29        http://actrisexample.eu/ns/Instrument_serial_number
# ..                                                        ...
# 173                       http://actrisexample.eu/ns/keywords
# 174                   http://actrisexample.eu/ns/Station_name
# 175                         http://actrisexample.eu/ns/source
# 176                        http://actrisexample.eu/ns/license
# 177               http://actrisexample.eu/ns/naming_authority
# 178            http://actrisexample.eu/ns/time_coverage_start
# 179           http://actrisexample.eu/ns/Zero/negative_values
# 180              http://actrisexample.eu/ns/time_coverage_end
# 181                   http://actrisexample.eu/ns/Organization
# 182               http://actrisexample.eu/ns/processing_level
# 183                 http://actrisexample.eu/ns/publisher_type
# 184                    http://actrisexample.eu/ns/institution
# 185              http://actrisexample.eu/ns/Station_longitude
# 186             http://actrisexample.eu/ns/Station_WMO_region
# 187                  http://actrisexample.eu/ns/Platform_code
# 188        http://actrisexample.eu/ns/geospatial_vertical_min
# 189               http://actrisexample.eu/ns/Instrument_model
# 190                         http://actrisexample.eu/ns/source
# 191                     http://actrisexample.eu/ns/Method_ref
# 192  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/318
# 193           http://actrisexample.eu/ns/Volume_std._pressure
# 194                http://actrisexample.eu/ns/Laboratory_code
# 195                                                ub8bL311C1
# 196                http://actrisexample.eu/ns/Sample_duration
# 197          http://actrisexample.eu/ns/publisher_institution
# 198   http://actrisexample.eu/ns/Humidity/temperature_control
# 199                       http://actrisexample.eu/ns/Timezone
# 200                http://actrisexample.eu/ns/Orig._time_res.
# 201                http://actrisexample.eu/ns/Resolution_code
# 202  http://vocab.nerc.ac.uk/collection/P07/current/3TUNI9CM/
#
#                                        property  \
# 0           http://actrisexample.eu/ns/hasvalue
# 1    http://www.w3.org/2000/01/rdf-schema#label
# 2    http://www.w3.org/2000/01/rdf-schema#label
# 3           http://actrisexample.eu/ns/hasvalue
# 4    http://www.w3.org/2000/01/rdf-schema#label
# 5    http://www.w3.org/2000/01/rdf-schema#label
# 6           http://actrisexample.eu/ns/hasvalue
# 7           http://actrisexample.eu/ns/hasvalue
# 8           http://actrisexample.eu/ns/hasvalue
# 9    http://www.w3.org/2000/01/rdf-schema#label
# 10          http://actrisexample.eu/ns/hasvalue
# 11          http://actrisexample.eu/ns/hasvalue
# 12          http://actrisexample.eu/ns/hasvalue
# 13   http://www.w3.org/2000/01/rdf-schema#label
# 14          http://actrisexample.eu/ns/hasvalue
# 15          http://actrisexample.eu/ns/hasvalue
# 16   http://www.w3.org/2000/01/rdf-schema#label
# 17          http://actrisexample.eu/ns/hasvalue
# 18          http://actrisexample.eu/ns/hasvalue
# 19          http://actrisexample.eu/ns/hasvalue
# 20   http://www.w3.org/2000/01/rdf-schema#label
# 21   http://www.w3.org/2000/01/rdf-schema#label
# 22   http://www.w3.org/2000/01/rdf-schema#label
# 23          http://actrisexample.eu/ns/hasvalue
# 24          http://actrisexample.eu/ns/hasvalue
# 25          http://actrisexample.eu/ns/hasvalue
# 26   http://www.w3.org/2000/01/rdf-schema#label
# 27          http://actrisexample.eu/ns/hasvalue
# 28          http://actrisexample.eu/ns/hasvalue
# 29          http://actrisexample.eu/ns/hasvalue
# ..                                          ...
# 173  http://www.w3.org/2000/01/rdf-schema#label
# 174  http://www.w3.org/2000/01/rdf-schema#label
# 175         http://actrisexample.eu/ns/hasvalue
# 176         http://actrisexample.eu/ns/hasvalue
# 177         http://actrisexample.eu/ns/hasvalue
# 178  http://www.w3.org/2000/01/rdf-schema#label
# 179         http://actrisexample.eu/ns/hasvalue
# 180  http://www.w3.org/2000/01/rdf-schema#label
# 181         http://actrisexample.eu/ns/hasvalue
# 182  http://www.w3.org/2000/01/rdf-schema#label
# 183         http://actrisexample.eu/ns/hasvalue
# 184         http://actrisexample.eu/ns/hasvalue
# 185  http://www.w3.org/2000/01/rdf-schema#label
# 186         http://actrisexample.eu/ns/hasvalue
# 187         http://actrisexample.eu/ns/hasvalue
# 188         http://actrisexample.eu/ns/hasvalue
# 189  http://www.w3.org/2000/01/rdf-schema#label
# 190  http://www.w3.org/2000/01/rdf-schema#label
# 191         http://actrisexample.eu/ns/hasvalue
# 192  http://www.w3.org/2000/01/rdf-schema#label
# 193         http://actrisexample.eu/ns/hasvalue
# 194         http://actrisexample.eu/ns/hasvalue
# 195  http://www.w3.org/2000/01/rdf-schema#label
# 196         http://actrisexample.eu/ns/hasvalue
# 197         http://actrisexample.eu/ns/hasvalue
# 198  http://www.w3.org/2000/01/rdf-schema#label
# 199  http://www.w3.org/2000/01/rdf-schema#label
# 200         http://actrisexample.eu/ns/hasvalue
# 201  http://www.w3.org/2000/01/rdf-schema#label
# 202  http://www.w3.org/2000/01/rdf-schema#label
#
#                                                                                                                                               object
# 0                                                                                                                                         timeSeries
# 1                                                                                                                                   Station_GAW_type
# 2                                                                                                                                              title
# 3                                                                                                                            2003-01-01T00:00:00_UTC
# 4                                                                                                                                    Sample_duration
# 5                                                                                                                                    Acknowledgement
# 6                     ,_"National_Oceanic_and_Atmospheric_Administration/Earth_System_Research_Laboratory/Global_Monitoring_Division,_NOAA/ESRL/GMD"
# 7                                                                                                                                         SOP=GAW227
# 8                                                                                                                                      0.047429_1/Mm
# 9                                                                                                                                   Station_altitude
# 10                                                                                                                                             Magee
# 11                                                                                                                      filter_absorption_photometer
# 12                                                                                                                                         Snowfield
# 13                                                                                                                                         Component
# 14                                                                                                                           Mike_Bergin,_John_Ogren
# 15                                                                                                                                                1h
# 16                                                                                                                                          measures
# 17                                                                                                                                              AE16
# 18                                                                                                                                                 G
# 19                                                                                                                                     72.5800018311
# 20                                                                                                                                     Set_type_code
# 21                                                                                                                                      date_created
# 22                                                                                                                                   Instrument_name
# 23                                                                                                                                               UTC
# 24                                                                                                                                    -38.4799995422
# 25                                                                                                                                          EBAS_1.1
# 26                                                                                                                                            Regime
# 27                                                                                                                                                 1
# 28                                                                                                                                               UTC
# 29                                                                                                                                               175
# ..                                                                                                                                               ...
# 173                                                                                                                                         keywords
# 174                                                                                                                                     Station_name
# 175                                                                                                                              surface_observation
# 176                                                                                                                          NOAA-ESRL:_,_GAW-WDCA:_
# 177                                                                                                                                     no.nilu.ebas
# 178                                                                                                                              time_coverage_start
# 179                                                         Zero_and_neg._values_may_appear_due_to_statistical_variations_at_very_low_concentrations
# 180                                                                                                                                time_coverage_end
# 181  US08L,_"National_Science_Foundation,_NSF/OPP,_Office_of_Polar_Programs",_NSF/OPP,_,_"4201_Wilson_Boulevard,_,_22230,_Arlington_VA,_USA",_,_,_,_
# 182                                                                                                                                 processing_level
# 183                                                                                                                                      institution
# 184                US08L,_National_Science_Foundation,_NSF/OPP,_Office_of_Polar_Programs,_NSF/OPP,_4201_Wilson_Boulevard,_,_22230,_Arlington_VA,_USA
# 185                                                                                                                                Station_longitude
# 186                                                                                                                                                6
# 187                                                                                                                                          DK0025S
# 188                                                                                                                                           3238.0
# 189                                                                                                                                 Instrument_model
# 190                                                                                                                                           source
# 191                                                                                                                               US08L_aethalometer
# 192                                                                                                                                        Component
# 193                                                                                                                                      1013.25_hPa
# 194                                                                                                                                            US08L
# 195                                                                                                                     filter_absorption_photometer
# 196                                                                                                                                               1h
# 197                                                                                         NILU_-_Norwegian_Institute_for_Air_Research,_ATMOS,_EBAS
# 198                                                                                                                     Humidity/temperature_control
# 199                                                                                                                                         Timezone
# 200                                                                                                                                              1mn
# 201                                                                                                                                  Resolution_code
# 202                                                                                                                                        Component
#
# [203 rows x 3 columns]

# %%
#display triples has value 'aerosol_absorption_coefficient'
q = query("""
prefix ae: <http://actrisexample.eu/ns/>
prefix dcterms: <http://purl.org/dc/terms/>
prefix envri: <http://envri.eu/ns/>
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix skos: <http://www.w3.org/2004/02/skos/core#>
prefix xml: <http://www.w3.org/XML/1998/namespace>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>


SELECT ?subject ?property ?object
WHERE {
VALUES ?object { 'aerosol_absorption_coefficient' }

 # ?subject ?property ?object .
 }
""")

display(q)
# Out:
#                                                     subject  \
# 0                      http://actrisexample.eu/ns/Component
# 1  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/318
# 2  http://vocab.nerc.ac.uk/collection/P07/current/3TUNI9CM/
# 3  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317
# 4  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/316
# 5                                               ub8bL312C17
#
#                                      property                          object
# 0         http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 1         http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 2         http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 3         http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 4         http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 5  http://www.w3.org/2000/01/rdf-schema#label  aerosol_absorption_coefficient

# %%
#display triples has value 'aerosol_absorption_coefficient'
#in current context, the result is the same with above cell
q = query("""
prefix ae: <http://actrisexample.eu/ns/>
prefix dcterms: <http://purl.org/dc/terms/>
prefix envri: <http://envri.eu/ns/>
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix skos: <http://www.w3.org/2004/02/skos/core#>
prefix xml: <http://www.w3.org/XML/1998/namespace>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>


SELECT ?subject ?property ?object
WHERE {
VALUES ?object { 'aerosol_absorption_coefficient' }
VALUES ?property {ae:hasvalue}
#VALUES ?subject {<http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317>}
 # ?subject ?property ?object .
 }
""")

display(q)
# Out:
#                                                     subject  \
# 0  http://vocab.nerc.ac.uk/collection/P07/current/3TUNI9CM/
# 1  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/316
# 2  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/318
# 3  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317
# 4                      http://actrisexample.eu/ns/Component
#
#                               property                          object
# 0  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 1  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 2  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 3  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient
# 4  http://actrisexample.eu/ns/hasvalue  aerosol_absorption_coefficient

# %%
#display the instrument filter_absorption_photometer and the variable it measures, aerosol_absorption_coefficient,
# also with its synonyms

q = query("""
prefix ae: <http://actrisexample.eu/ns/>
prefix dcterms: <http://purl.org/dc/terms/>
prefix envri: <http://envri.eu/ns/>
prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
prefix skos: <http://www.w3.org/2004/02/skos/core#>
prefix xml: <http://www.w3.org/XML/1998/namespace>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>


SELECT DISTINCT  ?instrument ?property ?parameter ?syn
WHERE {
VALUES ?property {ae:measures}
VALUES ?instrument {'filter_absorption_photometer'}
VALUES ?parameter {'aerosol_absorption_coefficient'}
 # ?instru ?property ?par .
 # ?instru rdfs:label ?instrument .
 # ?par rdfs:label ?parameter .
 # ?syn ae:hasvalue 'aerosol_absorption_coefficient' .
 }
""")

display(q)
# Out:
#                      instrument                             property  \
# 0  filter_absorption_photometer  http://actrisexample.eu/ns/measures
# 1  filter_absorption_photometer  http://actrisexample.eu/ns/measures
# 2  filter_absorption_photometer  http://actrisexample.eu/ns/measures
# 3  filter_absorption_photometer  http://actrisexample.eu/ns/measures
# 4  filter_absorption_photometer  http://actrisexample.eu/ns/measures
#
#                         parameter  \
# 0  aerosol_absorption_coefficient
# 1  aerosol_absorption_coefficient
# 2  aerosol_absorption_coefficient
# 3  aerosol_absorption_coefficient
# 4  aerosol_absorption_coefficient
#
#                                                         syn
# 0  http://vocab.nerc.ac.uk/collection/P07/current/3TUNI9CM/
# 1  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/317
# 2  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/318
# 3  http://codes.wmo.int/wmdr/ObservedVariableAtmosphere/316
# 4                      http://actrisexample.eu/ns/Component
